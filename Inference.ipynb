# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
from ultralytics import YOLO
from PIL import Image
import cv2
import shutil

# %%
model = YOLO('/content/drive/MyDrive/BRAE_428_Colab/runs/train9/weights/best.pt')

results = model.predict(
    source="/content/drive/MyDrive/BRAE_428_Colab/lettuce_pics", save=True
)

# %%
shutil.move('/content/runs/detect/predict2','/content/drive/MyDrive/BRAE_428_Colab')
# Out:
# '/content/drive/MyDrive/BRAE_428_Colab/predict2'
